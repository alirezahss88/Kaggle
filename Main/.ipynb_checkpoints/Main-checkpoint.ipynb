# %% [markdown]
# # import relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, plot_confusion_matrix
import tensorflow.keras.layers as layers
from tensorflow.keras import Sequential
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.compose import make_column_transformer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
import seaborn as sns
from sklearn.impute import KNNImputer
from sklearn import set_config
from sklearn.base import TransformerMixin, BaseEstimator
sns.set()
set_config(display="diagram")
np.set_printoptions(edgeitems = 10)

# %%
class Debug(BaseEstimator, TransformerMixin):

    def transform(self, X):
        print(X)
        
        # what other output you want
        return X

    def fit(self, X, y=None, **fit_params):
        return self

# %% [markdown]
# # Loading the training and test dataset

# %%
main_dir = "D:/Books/Machine Learning/Real_World_project/Titanic/dataset/"     # main directory of the dataset

# %%
train_dir = f"{main_dir}train.csv"          #dir of the training set
test_dir = f"{main_dir}test.csv"            #dir of the test set

# %%
# loading the datasets

train = pd.read_csv(train_dir)      
test = pd.read_csv(test_dir)

# train['Set'] = 'train'
# test['Set'] = 'test'

# %%
# add "survived" column to the test set and append to the training set

test['Survived'] = -1  

train_shape = train.shape
test_shape = test.shape

# data = train.append(test)
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train['Cabin'] = train['Cabin'].apply(lambda x: 1 if type(x) is str else 0)
train = pd.get_dummies(train, columns=['Sex', 'Embarked'], drop_first=True)

# %%
# droping non-significant columns
train = train.drop(['Name','Ticket', 'PassengerId'], axis=1)       

# filling NAN values
# ki = KNNImputer(n_neighbors=10)
# ki.fit(data['Age'][:train_shape[0]].to_numpy().reshape(-1,1))
# data['Age'] = ki.transform(data['Age'].to_numpy().reshape(-1,1))

# data['Age'].fillna(data['Age'].mean(), inplace=True)
# data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)
print(train.isna().sum())
train
# Out:
# Survived        0
# Pclass          0
# Age           177
# SibSp           0
# Parch           0
# Fare            0
# Cabin           0
# Sex_male        0
# Embarked_Q      0
# Embarked_S      0
# dtype: int64
#      Survived  Pclass   Age  SibSp  Parch     Fare  Cabin  Sex_male  \
# 0           0       3  22.0      1      0   7.2500      0         1
# 1           1       1  38.0      1      0  71.2833      1         0
# 2           1       3  26.0      0      0   7.9250      0         0
# 3           1       1  35.0      1      0  53.1000      1         0
# 4           0       3  35.0      0      0   8.0500      0         1
# ..        ...     ...   ...    ...    ...      ...    ...       ...
# 886         0       2  27.0      0      0  13.0000      0         1
# 887         1       1  19.0      0      0  30.0000      1         0
# 888         0       3   NaN      1      2  23.4500      0         0
# 889         1       1  26.0      0      0  30.0000      1         1
# ...

# %% [markdown]
# # Pipelin configuration

# %%
X_train = train.drop(['Survived'], axis=1)
y_train = train['Survived']

# %%
X_train
# Out:
#      Pclass   Age  SibSp  Parch     Fare  Cabin  Sex_male  Embarked_Q  \
# 0         3  22.0      1      0   7.2500      0         1           0
# 1         1  38.0      1      0  71.2833      1         0           0
# 2         3  26.0      0      0   7.9250      0         0           0
# 3         1  35.0      1      0  53.1000      1         0           0
# 4         3  35.0      0      0   8.0500      0         1           0
# ..      ...   ...    ...    ...      ...    ...       ...         ...
# 886       2  27.0      0      0  13.0000      0         1           0
# 887       1  19.0      0      0  30.0000      1         0           0
# 888       3   NaN      1      2  23.4500      0         0           0
# 889       1  26.0      0      0  30.0000      1         1           0
# 890       3  32.0      0      0   7.7500      0         1           1
#
#      Embarked_S
# 0             1
# 1             0
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
# defining preprocessing objects to be used in the pipeline
knn_cols = [1]
ss_cols = [1, 4]

# %%
preprocessing_1 = make_column_transformer(
                                        (KNNImputer(n_neighbors=10), knn_cols),
                                        remainder='passthrough'
)


preprocessing_2 = make_column_transformer(
                                        (StandardScaler(), ss_cols), remainder='passthrough'
)

preprocessing_3 = make_column_transformer(
                                        (Debug(), [0, 1, 2, 3, 4, 5, 6, 7, 8]), remainder='passthrough'
)

inner_pipe = make_pipeline(preprocessing_1, preprocessing_2, preprocessing_3)
inner_pipe
# Out:
# Pipeline(steps=[('columntransformer-1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('knnimputer',
#                                                   KNNImputer(n_neighbors=10),
#                                                   [1])])),
#                 ('columntransformer-2',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('standardscaler',
#                                                   StandardScaler(), [1, 4])])),
#                 ('columntransformer-3',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('debug', Debug(),
#                                                   [0, 1, 2, 3, 4, 5, 6, 7,
#                                                    8])]))])

# %%
algorithm = DecisionTreeClassifier(max_depth=5)

pipe = make_pipeline(inner_pipe, algorithm)
pipe
# Out:
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('columntransformer-1',
#                                   ColumnTransformer(remainder='passthrough',
#                                                     transformers=[('knnimputer',
#                                                                    KNNImputer(n_neighbors=10),
#                                                                    [1])])),
#                                  ('columntransformer-2',
#                                   ColumnTransformer(remainder='passthrough',
#                                                     transformers=[('standardscaler',
#                                                                    StandardScaler(),
#                                                                    [1, 4])])),
#                                  ('columntransformer-3',
#                                   ColumnTransformer(remainder='passthrough',
# ...

# %%
pipe.fit(X_train, y_train)
# Out:
# [[ 8.27377244e-01 -5.02445171e-01  2.20000000e+01  1.00000000e+00
#    0.00000000e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#    1.00000000e+00]
#  [-1.56610693e+00  7.86845294e-01  3.80000000e+01  1.00000000e+00
#    0.00000000e+00  1.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 8.27377244e-01 -4.88854258e-01  2.60000000e+01  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    1.00000000e+00]
#  [-1.56610693e+00  4.20730236e-01  3.50000000e+01  1.00000000e+00
#    0.00000000e+00  1.00000000e+00  0.00000000e+00  0.00000000e+00
#    1.00000000e+00]
#  [ 8.27377244e-01 -4.86337422e-01  3.50000000e+01  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#    1.00000000e+00]
#  [ 8.27377244e-01 -4.78116429e-01  2.96991176e+01  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  1.00000000e+00  1.00000000e+00
#    0.00000000e+00]
# ...

# %%
accuracy_score(y_train, pipe.predict(X_train))*100
# Out:
# [[ 0.73769513  0.61583843 22.          0.          0.          0.
#    3.          1.          0.          7.25        0.        ]
#  [-1.35557354 -1.62380254 38.          1.          1.          0.
#    1.          1.          0.         71.2833      1.        ]
#  [-1.35557354  0.61583843 26.          1.          0.          0.
#    3.          0.          0.          7.925       0.        ]
#  [-1.35557354  0.61583843 35.          1.          0.          0.
#    1.          1.          0.         53.1         1.        ]
#  [ 0.73769513  0.61583843 35.          0.          0.          0.
#    3.          0.          0.          8.05        0.        ]
#  [ 0.73769513 -1.62380254 29.69911765  0.          0.          1.
#    3.          0.          0.          8.4583      0.        ]
#  [ 0.73769513  0.61583843 54.          0.          0.          0.
#    1.          0.          0.         51.8625      1.        ]
#  [ 0.73769513  0.61583843  2.          0.          0.          0.
# ...

# %%
type(np.nan)
# Out:
# float

# %%
data['Sex'] = data['Sex'].map({'female':0, 'male':1})  #mapping male/female values to 1/0 respectively
data['Cabin'] = data['Cabin'].apply(lambda x: 1 if type(x) is str else 0)     #if passenger had cabin

data = pd.get_dummies(data, drop_first=True, columns=['Embarked'])
data
# Out:
#              Survived  Pclass  Sex        Age  SibSp  Parch      Fare  Cabin  \
# PassengerId
# 1                   0       3    1  22.000000      1      0    7.2500      0
# 2                   1       1    0  38.000000      1      0   71.2833      1
# 3                   1       3    0  26.000000      0      0    7.9250      0
# 4                   1       1    0  35.000000      1      0   53.1000      1
# 5                   0       3    1  35.000000      0      0    8.0500      0
# ...               ...     ...  ...        ...    ...    ...       ...    ...
# 1305               -1       3    1  29.699118      0      0    8.0500      0
# 1306               -1       1    0  39.000000      0      0  108.9000      1
# 1307               -1       3    1  38.500000      0      0    7.2500      0
# 1308               -1       3    1  29.699118      0      0    8.0500      0
# 1309               -1       3    1  29.699118      1      1   22.3583      0
#
# ...

# %%
std_scalar = StandardScaler()
std_scalar.fit(train[['Age', 'Fare']])
# Out:
# StandardScaler()

# %%
data[['Age', 'Fare']] = std_scalar.transform(data[['Age', 'Fare']])

# %%
plt.hist(data['Age'], bins=50, density=True);

# %%
data
# Out:
#              Survived  Pclass  Sex       Age  SibSp  Parch      Fare  Cabin  \
# PassengerId
# 1                   0       3    1 -0.530377      1      0 -0.502445      0
# 2                   1       1    0  0.571831      1      0  0.786845      1
# 3                   1       3    0 -0.254825      0      0 -0.488854      0
# 4                   1       1    0  0.365167      1      0  0.420730      1
# 5                   0       3    1  0.365167      0      0 -0.486337      0
# ...               ...     ...  ...       ...    ...    ...       ...    ...
# 1305               -1       3    1  0.000000      0      0 -0.486337      0
# 1306               -1       1    0  0.640719      0      0  1.544246      1
# 1307               -1       3    1  0.606275      0      0 -0.502445      0
# 1308               -1       3    1  0.000000      0      0 -0.486337      0
# 1309               -1       3    1  0.000000      1      1 -0.198244      0
#
#                Set  Embarked_Q  Embarked_S
# ...

# %%
X_train = data[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked_Q', 
                 'Embarked_S']].to_numpy()[:train.shape[0], :]
X_test = data[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked_Q', 
                 'Embarked_S']].to_numpy()[train.shape[0]:, :]

# %%
y_train = data['Survived'].to_numpy()[:train.shape[0]]

# %%
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape:  ', X_test.shape)
# Out:
# X_train.shape:  (891, 9)
# y_train.shape:  (891,)
# X_test.shape:   (418, 9)

# %% [markdown]
# # Test and train split

# %%
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2)

# %%
# X_train.shape

# %% [markdown]
# # Neural Network Classifier

# %%
# model = Sequential()
# model.add(layers.Dense(64, input_shape=(X_train.shape[1], ), activation='relu'))
# model.add(layers.Dense(1, activation='softmax'))

# %%
# model.compile(optimizer='adam',
#               loss='binary_crossentropy',
#               metrics=['accuracy'])

# %%
# model.fit(X_train, y_train, epochs=100, batch_size=128)

# %% [markdown]
# # Featur Engineering

# %%
data['Relative'] = data['SibSp'] + data['Parch']
data.drop(['SibSp', 'Parch'], axis=1, inplace=True)
data
# Out:
#              Survived  Pclass  Sex       Age      Fare  Cabin  Embarked_Q  \
# PassengerId
# 1                   0       3    1 -0.530377 -0.502445      0           0
# 2                   1       1    0  0.571831  0.786845      1           0
# 3                   1       3    0 -0.254825 -0.488854      0           0
# 4                   1       1    0  0.365167  0.420730      1           0
# 5                   0       3    1  0.365167 -0.486337      0           0
# ...               ...     ...  ...       ...       ...    ...         ...
# 1305               -1       3    1  0.012539 -0.486337      0           0
# 1306               -1       1    0  0.640719  1.544246      1           0
# 1307               -1       3    1  0.606275 -0.502445      0           0
# 1308               -1       3    1  0.012539 -0.486337      0           0
# 1309               -1       3    1  0.012539 -0.198244      0           0
#
#              Embarked_S  Relative
# PassengerId
# ...

# %%
X_train = data[['Pclass', 'Sex', 'Age', 'Fare', 'Cabin', 'Embarked_Q', 
                 'Embarked_S', 'Relative']].to_numpy()[:train.shape[0], :]
X_test = data[['Pclass', 'Sex', 'Age', 'Fare', 'Cabin', 'Embarked_Q', 
                 'Embarked_S', 'Relative']].to_numpy()[train.shape[0]:, :]

# %% [markdown]
# # Random Forest Classifier

# %%
rf = RandomForestClassifier()

# %%
param_grid = {'criterion': ['gini', 'entropy'],
               'max_depth': np.logspace(9, 13, 5, base=2, dtype=np.int16),
              'n_estimators': np.logspace(4, 9, 6, base=2, dtype=np.int16)}
param_grid
# Out:
# {'criterion': ['gini', 'entropy'],
#  'max_depth': array([ 512, 1024, 2048, 4096, 8192], dtype=int16),
#  'n_estimators': array([ 16,  32,  64, 128, 256, 512], dtype=int16)}

# %%
gs = GridSearchCV(rf, param_grid=param_grid, cv=5, verbose=1, n_jobs=-1)
gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': array([ 512, 1024, 2048, 4096, 8192], dtype=int16),
#                          'n_estimators': array([ 16,  32,  64, 128, 256, 512], dtype=int16)},
#              verbose=1)

# %%
gs.best_score_
# Out:
# 0.8204695248258114

# %%
gs.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 512, 'n_estimators': 32}

# %%
train['Pclass'].corr(train['Fare'])
# Out:
# -0.5494996199439078

# %%
from sklearn.preprocessing import KBinsDiscretizer
X = [[-2, 1, -4,   -1],
     [-1, 2, -3, -0.5],
     [ 0, 3, -2,  0.5],
     [ 1, 4, -1,    2]]

# %%
est = KBinsDiscretizer(n_bins=3, encode='onehot', strategy='uniform')
est.fit(X)
Xt = est.transform(X)
Xt
# Out:
# <4x12 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16 stored elements in Compressed Sparse Row format>
