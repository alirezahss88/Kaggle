# %% [markdown]
# # import relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import tensorflow.keras.layers as layers
from tensorflow.keras import Sequential

# %% [markdown]
# # Loading the training and test dataset

# %%
data_dir = "D:/Books/Machine Learning/Real_World_project/Titanic/dataset/"

# %%
train_dir = f"{data_dir}train.csv"
test_dir = f"{data_dir}test.csv"

# %%
train = pd.read_csv(train_dir, index_col='PassengerId')

# %%
train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
train = train.drop(['Name', 'Cabin', 'Ticket'], axis=1)
train['Age'].fillna(train['Age'].mean(), inplace=True)
train['Embarked'].fillna(train['Embarked'].mode()[0], inplace=True)
train.head()
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 1                   0       3    male  22.0      1      0   7.2500        S
# 2                   1       1  female  38.0      1      0  71.2833        C
# 3                   1       3  female  26.0      0      0   7.9250        S
# 4                   1       1  female  35.0      1      0  53.1000        S
# 5                   0       3    male  35.0      0      0   8.0500        S

# %%
train['Sex'] = train['Sex'].map({'female':0, 'male':1}) 
train = pd.get_dummies(train, drop_first=True)

# %%
train.head(10)
# Out:
#              Survived  Pclass  Sex        Age  SibSp  Parch     Fare  \
# PassengerId
# 1                   0       3    1  22.000000      1      0   7.2500
# 2                   1       1    0  38.000000      1      0  71.2833
# 3                   1       3    0  26.000000      0      0   7.9250
# 4                   1       1    0  35.000000      1      0  53.1000
# 5                   0       3    1  35.000000      0      0   8.0500
# 6                   0       3    1  29.699118      0      0   8.4583
# 7                   0       1    1  54.000000      0      0  51.8625
# 8                   0       3    1   2.000000      3      1  21.0750
# 9                   1       3    0  27.000000      0      2  11.1333
# 10                  1       2    0  14.000000      1      0  30.0708
#
#              Embarked_Q  Embarked_S
# PassengerId
# 1                     0           1
# 2                     0           0
# 3                     0           1
# ...

# %%
std_scalar = StandardScaler()
std_scalar.fit(train[['Age', 'Fare']])
# Out:
# StandardScaler()

# %%
train[['Age', 'Fare']] = std_scalar.transform(train[['Age', 'Fare']])

# %%
train
# Out:
#              Survived  Pclass  Sex       Age  SibSp  Parch      Fare  \
# PassengerId
# 1                   0       3    1 -0.592481      1      0 -0.502445
# 2                   1       1    0  0.638789      1      0  0.786845
# 3                   1       3    0 -0.284663      0      0 -0.488854
# 4                   1       1    0  0.407926      1      0  0.420730
# 5                   0       3    1  0.407926      0      0 -0.486337
# ...               ...     ...  ...       ...    ...    ...       ...
# 887                 0       2    1 -0.207709      0      0 -0.386671
# 888                 1       1    0 -0.823344      0      0 -0.044381
# 889                 0       3    0  0.000000      1      2 -0.176263
# 890                 1       1    1 -0.284663      0      0 -0.044381
# 891                 0       3    1  0.177063      0      0 -0.492378
#
#              Embarked_Q  Embarked_S
# PassengerId
# 1                     0           1
# 2                     0           0
# ...

# %%
X_train = train[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked_Q', 'Embarked_S']].to_numpy()

# %%
y_train = train['Survived'].to_numpy()

# %%
model = Sequential()
model.add(layers.Dense(64, input_shape=(X_train.shape[1], ), activation='relu'))
model.add(layers.Dense(1, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 0s 1ms/step - loss: 9.3960 - accuracy: 0.3838
# Epoch 2/100
# 14/14 [==============================] - 0s 1ms/step - loss: 9.3960 - accuracy: 0.3838
# Epoch 3/100
# 14/14 [==============================] - 0s 1ms/step - loss: 9.3960 - accuracy: 0.3838
# Epoch 4/100
# 14/14 [==============================] - 0s 1ms/step - loss: 9.3960 - accuracy: 0.3838
# Epoch 5/100
# 14/14 [==============================] - 0s 1ms/step - loss: 9.3960 - accuracy: 0.3838
# Epoch 6/100
# 14/14 [==============================] - 0s 1ms/step - loss: 9.3960 - accuracy: 0.3838
# Epoch 7/100
# 14/14 [==============================] - 0s 1ms/step - loss: 9.3960 - accuracy: 0.3838
# Epoch 8/100
# 14/14 [==============================] - 0s 1ms/step - loss: 9.3960 - accuracy: 0.3838
# Epoch 9/100
# 14/14 [==============================] - 0s 1ms/step - loss: 9.3960 - accuracy: 0.3838
# Epoch 10/100
# ...
